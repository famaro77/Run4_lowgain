# %%
# !git --version
# !git config --global user.name "Fernando"
# !git config --global user.email "famaro@gian.fis.uc.pt"
# !git init
# !git add .
# !git commit -m "Initial commit"
# !git rm -r --cached 001_environmental_paramters_SAVE_DATA
# !git commit -m "removed output

# %%
folder"
# !git branch -M main

# %%
# !git remote set-url origin https://github.com/CYGNO-Analysis/Run4_lowgain.git
# !git push -u origin main

# %%
# !ssh-keygen -t ed25519 -f ~/.ssh/id_ed25519 -N "" -C "famaro@gian.fis.uc.pt"

# %%
# !cat ~/.ssh/id_ed25519.pub

# %%
# !git clone git@github.com:CYGNO-Analysis/Run4_lowgain

# %%
# !ssh-keyscan github.com >> ~/.ssh/known_hosts

# %%
# !ssh -o BatchMode=yes -T git@github.com

# %%
# !git clone git@github.com:CYGNO-Analysis/Run4_lowgain.git

# %%
# !cd Run4_lowgain

# %%
# !git commit -m "initial commit"

# %%
# !ssh-keyscan github.com >> ~/.ssh/known_hosts

# %%
# !mkdir -p ~/.ssh
# !ssh-keyscan github.com >> ~/.ssh/known_hosts

# %%
# !git push --set-upstream origin main

# %%
# !ssh -T git@github.com

# %%
# !ls -al ~/.ssh
# Lists the files in your .ssh directory, if they exist

# %%
# !git status

# %%
# !echo ".ipynb_checkpoints/" >> .gitignore
# !git rm -r --cached .ipynb_checkpoints/

# %%
# !git add .gitignore
# !git commit -m "stop tracking notebook checkpoints"

# %%
# !git config --global user.email "famaro@gian.fis.uc.pt"
# !git config --global user.name "famaro77"

# %%
# !git status

# %%
# !git add 002_energy_normalization_HG_LH.ipynb

# %%
# !git add cuts_cygno.py

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git remote -v

# %%
# !git remote set-url origin git@github.com:famaro77/Run4_lowgain.git

# %%
# !git push --set-upstream origin main
# Out:
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (10/10), 1.12 MiB | 6.07 MiB/s, done.
# Total 10 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# To github.com:famaro77/Run4_lowgain.git
#    1403e4d..06fc20e  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git add .

# %%
# !git commit -m "added 002 notebook"
# Out:
# [main 9270671] added 002 notebook
#  11 files changed, 7765 insertions(+), 6938 deletions(-)
#  rewrite 001_environmental_parameters.ipynb (78%)
#  create mode 100644 002_energy_normalization_HG_LH.ipynb
#  create mode 100644 Git_configurations.ipynb
#  create mode 100644 __pycache__/configs.cpython-311.pyc
#  create mode 100644 __pycache__/configs.cpython-39.pyc
#  create mode 100644 __pycache__/cuts_cygno.cpython-39.pyc
#  create mode 100644 __pycache__/functions.cpython-311.pyc
#  create mode 100644 __pycache__/functions.cpython-39.pyc
#  create mode 100644 cuts_cygno.py
#  create mode 100644 high_gain_low_gain.ipynb

# %%
# !echo "__pycache__/" >> .gitignore
# !echo "*.pyc" >> .gitignore
# !git rm -r --cached __pycache__/
# !git add .gitignore
# !git commit -m "ignore pycache files"
# Out:
# rm '__pycache__/configs.cpython-311.pyc'
# rm '__pycache__/configs.cpython-39.pyc'
# rm '__pycache__/cuts_cygno.cpython-39.pyc'
# rm '__pycache__/functions.cpython-311.pyc'
# rm '__pycache__/functions.cpython-39.pyc'
# [main db85b80] ignore pycache files
#  6 files changed, 2 insertions(+)
#  delete mode 100644 __pycache__/configs.cpython-311.pyc
#  delete mode 100644 __pycache__/configs.cpython-39.pyc
#  delete mode 100644 __pycache__/cuts_cygno.cpython-39.pyc
#  delete mode 100644 __pycache__/functions.cpython-311.pyc
#  delete mode 100644 __pycache__/functions.cpython-39.pyc
